# %%
import pandas as pd
import numpy as np

# %%
#loding Dataset

# %%
orders = pd.read_csv('Orders.csv')

# %%
Customers = pd.read_csv('Customers.csv')

# %%
Agents = pd.read_csv('Agents.csv')

# %%
orders.head()
# Out:
#    ORD_NUM  ORD_AMOUNT  ADVANCE_AMOUNT    ORD_DATE CUST_CODE AGENT_CODE  \
# 0   200100      1000.0           600.0  2008-01-08    C00015     A003
# 1   200110      3000.0           500.0  2008-04-15    C00019     A010
# 2   200107      4500.0           900.0  2008-08-30    C00007     A010
# 3   200112      2000.0           400.0  2008-05-30    C00016     A007
# 4   200113      4000.0           600.0  2008-06-10    C00022     A002
#
#   ORD_DESCRIPTION
# 0           SOD\r
# 1           SOD\r
# 2           SOD\r
# 3           SOD\r
# 4           SOD\r

# %%
Customers.head()
# Out:
#   CUST_CODE  CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0    C00013     Holmes  London                                    London
# 1    C00001    Micheal  New York                                New York
# 2    C00020     Albert  New York                                New York
# 3    C00025  Ravindran  Bangalore                              Bangalore
# 4    C00024       Cook  London                                    London
#
#   CUST_COUNTRY  GRADE  OPENING_AMT  RECEIVE_AMT  PAYMENT_AMT  OUTSTANDING_AMT  \
# 0           UK      2       6000.0       5000.0       7000.0           4000.0
# 1          USA      2       3000.0       5000.0       2000.0           6000.0
# 2          USA      3       5000.0       7000.0       6000.0           6000.0
# 3        India      2       5000.0       7000.0       4000.0           8000.0
# 4           UK      2       4000.0       9000.0       7000.0           6000.0
#
#   PHONE_NO AGENT_CODE
# 0  BBBBBBB     A003
# ...

# %%
Agents.head()
# Out:
#   AGENT_CODE                                AGENT_NAME  \
# 0     A007    Ramasundar
# 1     A003    Alex
# 2     A008    Alford
# 3     A011    Ravi Kumar
# 4     A010    Santakumar
#
#                           WORKING_AREA  COMMISSION         PHONE_NO COUNTRY
# 0  Bangalore                                  0.15  077-25814763         \r
# 1  London                                     0.13  075-12458969         \r
# 2  New York                                   0.12  044-25874365         \r
# 3  Bangalore                                  0.15  077-45625874         \r
# 4  Chennai                                    0.14  007-22388644         \r

# %%
# agent Code is Present in all the three tables 
# Customer code is present in customer and order table

# %%
order = pd.DataFrame(orders)

# %%
customer = pd.DataFrame(Customers)

# %%
agent= pd.DataFrame(Agents)

# %%
agent.head()
# Out:
#   AGENT_CODE                                AGENT_NAME  \
# 0     A007    Ramasundar
# 1     A003    Alex
# 2     A008    Alford
# 3     A011    Ravi Kumar
# 4     A010    Santakumar
#
#                           WORKING_AREA  COMMISSION         PHONE_NO COUNTRY
# 0  Bangalore                                  0.15  077-25814763         \r
# 1  London                                     0.13  075-12458969         \r
# 2  New York                                   0.12  044-25874365         \r
# 3  Bangalore                                  0.15  077-45625874         \r
# 4  Chennai                                    0.14  007-22388644         \r

# %%
merge_colum=pd.merge(orders,Customers)

# %%
merge_colum
# Out:
#     ORD_NUM  ORD_AMOUNT  ADVANCE_AMOUNT    ORD_DATE CUST_CODE AGENT_CODE  \
# 0    200100      1000.0           600.0  2008-01-08    C00015     A003
# 1    200127      2500.0           400.0  2008-07-20    C00015     A003
# 2    200110      3000.0           500.0  2008-04-15    C00019     A010
# 3    200107      4500.0           900.0  2008-08-30    C00007     A010
# 4    200119      4000.0           700.0  2008-09-16    C00007     A010
# 5    200135      2000.0           800.0  2008-09-16    C00007     A010
# 6    200112      2000.0           400.0  2008-05-30    C00016     A007
# 7    200113      4000.0           600.0  2008-06-10    C00022     A002
# 8    200123       500.0           100.0  2008-09-16    C00022     A002
# 9    200126       500.0           100.0  2008-06-24    C00022     A002
# 10   200102      2000.0           300.0  2008-05-25    C00012     A012
# 11   200131       900.0           150.0  2008-08-26    C00012     A012
# ...

# %%
Num_order_country = merge_colum.loc[:,['ORD_NUM','CUST_COUNTRY']]

# %%
Num_order_country
# Out:
#     ORD_NUM CUST_COUNTRY
# 0    200100           UK
# 1    200127           UK
# 2    200110        India
# 3    200107        India
# 4    200119        India
# 5    200135        India
# 6    200112        India
# 7    200113        India
# 8    200123        India
# 9    200126        India
# 10   200102          USA
# 11   200131          USA
# 12   200114          USA
# 13   200122       Canada
# 14   200118           UK
# 15   200121       Canada
# 16   200108       Canada
# 17   200130        India
# 18   200105        India
# 19   200134    Australia
# 20   200103    Australia
# 21   200109        India
# 22   200101          USA
# 23   200111          USA
# 24   200104       Canada
# 25   200106        India
# 26   200125    Australia
# 27   200117        India
# 28   200120        India
# 29   200128        India
# 30   200133        India
# 31   200116           UK
# 32   200124        India
# 33   200129           UK

# %%
order_each_country= Num_order_country.groupby('CUST_COUNTRY')

# %%
Complete_assigment =order_each_country.count()

# %%
import json

# %%
df.to_json('Complete_assigment')
