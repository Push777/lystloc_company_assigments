# %%
import pandas as pd
import numpy as np

# %%
orders = pd.read_csv('Orders.csv')

# %%
Customers = pd.read_csv('Customers.csv')

# %%
Agents = pd.read_csv('Agents.csv')

# %%
Agents.head()
# Out:
#   AGENT_CODE                                AGENT_NAME  \
# 0     A007    Ramasundar
# 1     A003    Alex
# 2     A008    Alford
# 3     A011    Ravi Kumar
# 4     A010    Santakumar
#
#                           WORKING_AREA  COMMISSION         PHONE_NO COUNTRY
# 0  Bangalore                                  0.15  077-25814763         \r
# 1  London                                     0.13  075-12458969         \r
# 2  New York                                   0.12  044-25874365         \r
# 3  Bangalore                                  0.15  077-45625874         \r
# 4  Chennai                                    0.14  007-22388644         \r

# %%
Agents.drop(Agents.columns[-1], axis=1, inplace=True)

# %%
Agents.head()
# Out:
#   AGENT_CODE                                AGENT_NAME  \
# 0     A007    Ramasundar
# 1     A003    Alex
# 2     A008    Alford
# 3     A011    Ravi Kumar
# 4     A010    Santakumar
#
#                           WORKING_AREA  COMMISSION         PHONE_NO
# 0  Bangalore                                  0.15  077-25814763
# 1  London                                     0.13  075-12458969
# 2  New York                                   0.12  044-25874365
# 3  Bangalore                                  0.15  077-45625874
# 4  Chennai                                    0.14  007-22388644

# %%
merge_colum=pd.merge(orders,Customers)

# %%
merge_colum
# Out:
#     ORD_NUM  ORD_AMOUNT  ADVANCE_AMOUNT    ORD_DATE CUST_CODE AGENT_CODE  \
# 0    200100      1000.0           600.0  2008-01-08    C00015     A003
# 1    200127      2500.0           400.0  2008-07-20    C00015     A003
# 2    200110      3000.0           500.0  2008-04-15    C00019     A010
# 3    200107      4500.0           900.0  2008-08-30    C00007     A010
# 4    200119      4000.0           700.0  2008-09-16    C00007     A010
# 5    200135      2000.0           800.0  2008-09-16    C00007     A010
# 6    200112      2000.0           400.0  2008-05-30    C00016     A007
# 7    200113      4000.0           600.0  2008-06-10    C00022     A002
# 8    200123       500.0           100.0  2008-09-16    C00022     A002
# 9    200126       500.0           100.0  2008-06-24    C00022     A002
# 10   200102      2000.0           300.0  2008-05-25    C00012     A012
# 11   200131       900.0           150.0  2008-08-26    C00012     A012
# ...

# %%
Three_merge = pd.merge(merge_colum,Agents,full_on='AGENT_CODE')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-05de927abd1c> in <module>
# ----> 1 Three_merge = pd.merge(merge_colum,Agents,full_on='AGENT_CODE')
#
# TypeError: merge() got an unexpected keyword argument 'full_on'

# %%
import pandas as pd
from functools import reduce

# compile the list of dataframes you want to merge
data_frames = [orders,Customers,Agents]
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['AGENT_CODE'],
                                            how='outer'), data_frames)

# %%
Join_data=df_merged
Join_data
# Out:
#     ORD_NUM  ORD_AMOUNT  ADVANCE_AMOUNT    ORD_DATE CUST_CODE_x AGENT_CODE  \
# 0    200100      1000.0           600.0  2008-01-08      C00015     A003
# 1    200100      1000.0           600.0  2008-01-08      C00015     A003
# 2    200127      2500.0           400.0  2008-07-20      C00015     A003
# 3    200127      2500.0           400.0  2008-07-20      C00015     A003
# 4    200110      3000.0           500.0  2008-04-15      C00019     A010
# ..      ...         ...             ...         ...         ...        ...
# 81   200125      2000.0           600.0  2008-10-10      C00018     A005
# 82   200115      2000.0          1200.0  2008-02-08      C00013     A013
# 83   200132      4000.0          2000.0  2008-08-15      C00013     A013
# 84   200117       800.0           200.0  2008-10-20      C00014     A001
# 85   200116       500.0           100.0  2008-07-13      C00010     A009
#
#    ORD_DESCRIPTION CUST_CODE_y    CUST_NAME  \
# ...

# %%
Data=Join_data.dropna()

# %%
Ass_1 = Data.loc[:,['CUST_NAME','CUST_NAME','AGENT_NAME','WORKING_AREA_y','ORD_NUM','ORD_AMOUNT','ORD_DESCRIPTION']]

# %%
Ass_1
# Out:
#       CUST_NAME    CUST_NAME                                AGENT_NAME  \
# 0        Holmes       Holmes  Alex
# 1        Stuart       Stuart  Alex
# 2        Holmes       Holmes  Alex
# 3        Stuart       Stuart  Alex
# 4   Yearannaidu  Yearannaidu  Santakumar
# ..          ...          ...                                       ...
# 79      Fleming      Fleming  Anderson
# 80        Jacks        Jacks  Anderson
# 81      Winston      Winston  Anderson
# 84   Rangarappa   Rangarappa  Subbarao
# 85      Charles      Charles  Benjamin
#
#                          WORKING_AREA_y  ORD_NUM  ORD_AMOUNT ORD_DESCRIPTION
# 0   London                                200100      1000.0           SOD\r
# 1   London                                200100      1000.0           SOD\r
# 2   London                                200127      2500.0           SOD\r
# 3   London                                200127      2500.0           SOD\r
# ...

# %%
Ass_1.to_csv('Ass_1_csv_file')
